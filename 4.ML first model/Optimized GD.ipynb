# %% [markdown]
# ## Linear Regression : Gradient Descent Method.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('test.csv')
df.head()
# Out:
#    house_size  price_usd
# 0         507     126974
# 1         524     128028
# 2         540     132403
# 3         563     134615
# 4         569     132594

# %%
x = df['house_size'].values
y = df['price_usd'].values

x_mean = np.mean(x)
y_mean = np.mean(y)

x_std = np.std(x)
y_std = np.std(y)

x = (x - x_mean)/(x_std)
y = (y - y_mean)/(y_std)

# %%
# parameters : slope, intercept
m = 0
b = 0

# hyperparameters : steps, learning rate, length
steps = 1000
lr = 0.01
n = len(x)

residual_list = []

# %%
for i in range(steps):
    y_pred = m*x + b
    residual = y - y_pred

    loss_mse = (1/n)*np.sum((residual) ** 2)  # at each step
    residual_list.append(loss_mse)

    # gradients
    dm = (-2/n) * np.sum(x * residual)
    db = (-2/n) * np.sum(residual)

    # upadating the weights
    m = m - (lr*dm)
    b = b - (lr*db)

    print(f"step {i}, slope:{m}, intercept:{b}, loss:{loss}")
# Out:
# step 0, slope:0.019741969179954633, intercept:6.4099668968924135e-18, loss:0.02563663224430309
# step 1, slope:0.039089098976310174, intercept:1.2819933793784827e-17, loss:0.02563663224430309
# step 2, slope:0.05804928617673861, intercept:1.8894739022865872e-17, loss:0.02563663224430309
# step 3, slope:0.07663026963315847, intercept:2.5891238838428182e-17, loss:0.02563663224430309
# step 4, slope:0.09483963342044993, intercept:3.213362490141491e-17, loss:0.02563663224430309
# step 5, slope:0.11268480993199557, intercept:3.8082744505066695e-17, loss:0.02563663224430309
# step 6, slope:0.1301730829133103, intercept:4.4367025776529844e-17, loss:0.02563663224430309
# step 7, slope:0.14731159043499875, intercept:4.998098371237026e-17, loss:0.02563663224430309
# step 8, slope:0.16410732780625342, intercept:5.601389373297489e-17, loss:0.02563663224430309
# step 9, slope:0.18056715043008298, intercept:6.158595646033888e-17, loss:0.02563663224430309
# ...

# %%
print("✅ final slope :",round(m,3))
print("✅ final intercept :",round(b,3))
# Out:
# ✅ final slope : 0.987
# ✅ final intercept : 0.0

# %%
# final plot
plt.scatter(x,y,color = 'yellow', edgecolor = 'red', s = 100, label = 'actual data')
