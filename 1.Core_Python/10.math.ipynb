# %% [markdown]
# # <span style='color:orange'>Math Module</span>

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
print(math.sqrt(17))
# Out:
# 4.123105625617661

# %%
math.pow(9,2)
# Out:
# 81.0

# %%
math.log(100,10) # here base is 10.
# Out:
# 2.0

# %% [markdown]
# ### <span style='color:orange'>Trigonometry</span>

# %%
angle_X = math.radians(45)

print(math.sin(angle_X))
print(math.cos(angle_X))
print(math.tan(angle_X))
# Out:
# 0.7071067811865475
# 0.7071067811865476
# 0.9999999999999999

# %%
math.sin(0)
# Out:
# 0.0

# %%
math.tan(0)
# Out:
# 0.0

# %% [markdown]
# ### <span style='color:orange'>Mathematical constants</span>

# %%
radius = 10
area = math.pi * (radius**2)
circumference = math.pi * 2 * radius

print(area)
print(circumference)
# Out:
# 314.1592653589793
# 62.83185307179586

# %%
# factorial
math.factorial(5)
# Out:
# 120

# %%
# round up
math.ceil(4.5)
# Out:
# 5

# %%
math.ceil(4.1)
# Out:
# 5

# %%
# round down
math.floor(5.9)
# Out:
# 5

# %% [markdown]
# ### <span style='color:orange'>Logarithm</span>

# %%
math.log2(32)
# Out:
# 5.0

# %%
math.log10(1000)
# Out:
# 3.0

# %% [markdown]
# ### <span style='color:orange'>GCD</span>

# %%
math.gcd(48,24)
# Out:
# 24

# %%
# random eg.

import random
random_list = [random.randint(10,50) for _ in range(5)]
print(random_list)

roots = [math.sqrt(x) for x in random_list]
print(roots)
# Out:
# [35, 19, 40, 27, 24]
# [5.916079783099616, 4.358898943540674, 6.324555320336759, 5.196152422706632, 4.898979485566356]
