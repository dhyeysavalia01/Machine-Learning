# %% [markdown]
# # Broadcasting

# %%
import numpy as np

miles = np.array([4,5,7.2])
kms = miles * 1.6
kms
# Out:
# array([ 6.4 ,  8.  , 11.52])

# %% [markdown]
# ![image.png](attachment:image.png)
