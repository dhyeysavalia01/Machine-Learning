# %% [markdown]
# # Matrices

# %%
import numpy as np

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data = np.array([[1,2],[3,4],[5,6]])
data
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(data.max())
print(data.min())
print(data.sum())
# Out:
# 6
# 1
# 21

# %%
print(data.max(axis=0))
print(data.sum(axis=0))
# Out:
# [5 6]
# [ 9 12]

# %%
print(data.max(axis=1))
print(data.sum(axis=1))
# Out:
# [2 4 6]
# [ 3  7 11]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data = np.array([[1,2],[3,4]])
ones = np.array([[1,1],[1,1]])

# %%
data + ones
# Out:
# array([[2, 3],
#        [4, 5]])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = np.ones((3,2)) # given parameters as rown,columns
x
# Out:
# array([[1., 1.],
#        [1., 1.],
#        [1., 1.]])

# %%
x.shape
# Out:
# (3, 2)

# %%
z = np.zeros((3,2))
z
# Out:
# array([[0., 0.],
#        [0., 0.],
#        [0., 0.]])

# %%
rng = np.random.default_rng()
rng.random((3,2))
# Out:
# array([[0.15334696, 0.05114265],
#        [0.41171637, 0.90358317],
#        [0.63057108, 0.05237728]])

# %% [markdown]
# ### Transposing a matrix

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
arr = np.arange(1,7).reshape((3, 2))
arr
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
arr.T
# Out:
# array([[1, 3, 5],
#        [2, 4, 6]])

# %%
np.flip(arr)
# Out:
# array([[6, 5],
#        [4, 3],
#        [2, 1]])
